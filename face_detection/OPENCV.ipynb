# %%
import cv2

face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
# eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')
img = cv2.imread('h.jpeg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces = face_cascade.detectMultiScale(gray)

for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    
cv2.imshow('img',img)

k = cv2.waitKey(0)
if k == 27:         # wait for ESC key to exit
    cv2.destroyAllWindows()
elif k == ord('s'): # wait for 's' key to save and exit
    cv2.imwrite('messigray.png',img)
    cv2.destroyAllWindows()

# %%
# Out:
# usage: ipykernel_launcher.py [-h] [--input INPUT] [--thr THR] [--width WIDTH]
#                              [--height HEIGHT]
# ipykernel_launcher.py: error: unrecognized arguments: -f /run/user/1000/jupyter/kernel-7ae9ca95-da3d-433e-b152-57e75681e26e.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /home/ahsankhan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2969: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# Out:
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
# row
